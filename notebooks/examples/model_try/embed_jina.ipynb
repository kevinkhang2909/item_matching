# %%
from pathlib import Path
import polars as pl
from datasets import Dataset
import numpy as np
from autofaiss import build_index
from core_pro.ultilities import make_dir
from sentence_transformers import SentenceTransformer
import sys
sys.path.extend([str(Path.home() / 'PycharmProjects/item_matching')])

from notebooks.benchmark.data_load import load

# %%
df, col, path = load()
df.head()
# Out:
# Data Shape: (72110, 6)
# shape: (5, 6)
# ┌─────┬─────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ id  ┆ q_item_id   ┆ q_level1_global_b ┆ q_item_name       ┆ q_link_first_imag ┆ q_item_name_clea │
# │ --- ┆ ---         ┆ e_category        ┆ ---               ┆ e                 ┆ n                │
# │ u32 ┆ i64         ┆ ---               ┆ str               ┆ ---               ┆ ---              │
# │     ┆             ┆ str               ┆                   ┆ str               ┆ str              │
# ╞═════╪═════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ 0   ┆ 25622409846 ┆ Men Shoes         ┆ Dép da nam        ┆ https://cf.shopee ┆ dép da nam       │
# │     ┆             ┆                   ┆ changfa hàng  moi ┆ .sg/file/vn-1…    ┆ changfa hàng     │
# │     ┆             ┆                   ┆ v…                ┆                   ┆ moi v…           │
# │ 1   ┆ 7669916630  ┆ Men Shoes         ┆ Giày Sneaker Nam  ┆ https://cf.shopee ┆ giày sneaker nam │
# │     ┆             ┆                   ┆ Đế Cao Su Non…    ┆ .sg/file/d771…    ┆ đế cao su non…   │
# │ 2   ┆ 25827115226 ┆ Men Shoes         ┆ Giày_Nike Air     ┆ https://cf.shopee ┆ giày_nike air    │
# │     ┆             ┆                   ┆ Force 1 Louis Vu… ┆ .sg/file/sg-1…    ┆ force 1 louis    │
# │     ┆             ┆                   ┆                   ┆                   ┆ vu…              │
# │ 3   ┆ 23231741326 ┆ Men Shoes         ┆ Dép sandal nam    ┆ https://cf.shopee ┆ dép sandal nam   │
# │     ┆             ┆                   ┆ Quai Mảnh Fashi…  ┆ .sg/file/vn-1…    ┆ quai mảnh fashi… │
# │ 4   ┆ 22885058948 ┆ Men Shoes         ┆ Dép Quai Ngang    ┆ https://cf.shopee ┆ dép quai ngang   │
# │     ┆             ┆                   ┆ M.L.B Mound Mic…  ┆ .sg/file/vn-1…    ┆ m.l.b mound mic… │
# └─────┴─────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %%
# df['q_item_name_clean'].to_list()

# %%
path_tmp_array = Path('tmp/array')
path_tmp_ds = Path('tmp/ds')
make_dir(path_tmp_ds)
make_dir(path_tmp_array)

file_embed = path_tmp_array / f'jina_embed.npy'
if not file_embed.exists():
    model = SentenceTransformer("jinaai/jina-embeddings-v3", trust_remote_code=True)
    task = 'text-matching'
    embeddings = model.encode(
        df['q_item_name_clean'].to_list(),
        task=task,
        prompt_name=task,
        show_progress_bar=True
    )
    np.save(file_embed, embeddings)
else:
    embeddings = np.load(file_embed)
print(embeddings.shape)
# Out:
# Batches:   0%|          | 0/2254 [00:00<?, ?it/s]
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# ...
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# (72110, 1024)

# %%
df = df.with_columns(pl.Series(values=embeddings, name='embed'))
dataset = Dataset.from_polars(df)
dataset.set_format(type='numpy', columns=['embed'], output_all_columns=True)

# %%
path_index = Path('tmp/index')
build_index(
    embeddings=embeddings,
    index_path=str(path_index / f'ip.index'),
    index_infos_path=str(path_index / f'index.json'),
    save_on_disk=True,
    metric_type='ip',
    verbose=30,
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 24672.38it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.83it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# (<faiss.swigfaiss_avx2.IndexHNSWFlat; proxy of <Swig Object of type 'faiss::IndexHNSWFlat *' at 0x742fdb92e670> >,
#  {'index_key': 'HNSW32',
#   'index_param': 'efSearch=814',
#   'index_path': 'tmp/index/ip.index',
#   'size in bytes': 314987402,
#   'avg_search_speed_ms': 3.7758498293187586,
#   '99p_search_speed_ms': 12.999637332832208,
#   'reconstruction error %': 0.0,
#   'nb vectors': 72110,
#   'vectors dimension': 1024,
#   'compression ratio': 0.9376964225381941})

# %%
# add index
dataset.load_faiss_index('embed', path_index / f'ip.index')

# %%
score, result = dataset.get_nearest_examples_batch(
    'embed',
    np.asarray(dataset['embed']),
    k=5
)

dict_ = {'score': [list(i) for i in score]}
df_score = pl.DataFrame(dict_)
df_result = (
    pl.DataFrame(result).drop(['embed'])
    .select(pl.all().name.prefix(f'db_'))
)

# %%
df_match = pl.concat([df.drop(['id']), df_result, df_score], how='horizontal')
col_explode = [i for i in df_match.columns if 'notebooks' in i] + ['score']
df_match = df_match.explode(col_explode)

# %%
df_match
# Out:
# shape: (360_550, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ q_item_id ┆ q_level1_ ┆ q_item_na ┆ q_link_fi ┆ … ┆ db_q_item ┆ db_q_link ┆ db_q_item ┆ score    │
# │ ---       ┆ global_be ┆ me        ┆ rst_image ┆   ┆ _name     ┆ _first_im ┆ _name_cle ┆ ---      │
# │ i64       ┆ _category ┆ ---       ┆ ---       ┆   ┆ ---       ┆ age       ┆ an        ┆ f32      │
# │           ┆ ---       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆          │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 278045080 ┆ Men Shoes ┆ （100%    ┆ https://c ┆ … ┆ （100%    ┆ https://c ┆ （100%    ┆ 0.99385  │
# │ 88        ┆           ┆ Auth      ┆ f.shopee. ┆   ┆ Auth      ┆ f.shopee. ┆ auth      ┆          │
# │           ┆           ┆ ）Giày    ┆ sg/file/s ┆   ┆ ）Giày    ┆ sg/file/s ┆ ）giày    ┆          │
# │           ┆           ┆ Thể Thao  ┆ g-1…      ┆   ┆ Thể Thao  ┆ g-1…      ┆ thể thao  ┆          │
┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.997246 │
# │ 23        ┆           ┆ ngang LV  ┆ f.shopee. ┆   ┆ ngang LV  ┆ f.shopee. ┆ ngang lv  ┆          │
# │           ┆           ┆ da cao    ┆ sg/file/v ┆   ┆ da cao    ┆ sg/file/v ┆ da cao    ┆          │
# │           ┆           ┆ cấp_D…    ┆ n-1…      ┆   ┆ cấp_D…    ┆ n-1…      ┆ cấp_d…    ┆          │
# │ 202882316 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép LV    ┆ https://c ┆ dép lv    ┆ 0.91091  │
# │ 23        ┆           ┆ ngang LV  ┆ f.shopee. ┆   ┆ quai da   ┆ f.shopee. ┆ quai da   ┆          │
# │           ┆           ┆ da cao    ┆ sg/file/v ┆   ┆ nam, Dép  ┆ sg/file/v ┆ nam, dép  ┆          │
# │           ┆           ┆ cấp_D…    ┆ n-1…      ┆   ┆ quai …    ┆ n-1…      ┆ quai …    ┆          │
# │ 202882316 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép nam   ┆ https://c ┆ dép nam   ┆ 0.875208 │
# │ 23        ┆           ┆ ngang LV  ┆ f.shopee. ┆   ┆ quai      ┆ f.shopee. ┆ quai      ┆          │
# │           ┆           ┆ da cao    ┆ sg/file/v ┆   ┆ ngang LV  ┆ sg/file/v ┆ ngang lv  ┆          │
# │           ┆           ┆ cấp_D…    ┆ n-1…      ┆   ┆ 2023 - d… ┆ n-1…      ┆ 2023 - d… ┆          │
# │ 202882316 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép Da    ┆ https://c ┆ dép da    ┆ 0.874898 │
# │ 23        ┆           ┆ ngang LV  ┆ f.shopee. ┆   ┆ Nam Quai  ┆ f.shopee. ┆ nam quai  ┆          │
# │           ┆           ┆ da cao    ┆ sg/file/v ┆   ┆ Ngang LV  ┆ sg/file/v ┆ ngang lv  ┆          │
# │           ┆           ┆ cấp_D…    ┆ n-1…      ┆   ┆ Cao C…    ┆ n-1…      ┆ cao c…    ┆          │
# │ 202882316 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép lê    ┆ https://c ┆ dép lê    ┆ 0.872743 │
# │ 23        ┆           ┆ ngang LV  ┆ f.shopee. ┆   ┆ nam quai  ┆ f.shopee. ┆ nam quai  ┆          │
# │           ┆           ┆ da cao    ┆ sg/file/v ┆   ┆ ngang     ┆ sg/file/v ┆ ngang     ┆          │
# │           ┆           ┆ cấp_D…    ┆ n-1…      ┆   ┆ chất liệ… ┆ n-1…      ┆ chất liệ… ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_match.filter(q_item_id=4992244030)
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ q_item_id ┆ q_level1_ ┆ q_item_na ┆ q_link_fi ┆ … ┆ db_q_item ┆ db_q_link ┆ db_q_item ┆ score    │
# │ ---       ┆ global_be ┆ me        ┆ rst_image ┆   ┆ _name     ┆ _first_im ┆ _name_cle ┆ ---      │
# │ i64       ┆ _category ┆ ---       ┆ ---       ┆   ┆ ---       ┆ age       ┆ an        ┆ f32      │
# │           ┆ ---       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆          │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │