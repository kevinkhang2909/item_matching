# %%
from pathlib import Path
import polars as pl
from datasets import Dataset
import numpy as np
from autofaiss import build_index
from core_pro.ultilities import make_dir
from sentence_transformers import SentenceTransformer
import sys
sys.path.extend([str(Path.home() / 'PycharmProjects/item_matching')])

from notebooks.benchmark.data_load import load

# %%
df, col, path = load()
df.head()
# Out:
# Data Shape: (72110, 6)
# shape: (5, 6)
# ┌─────┬─────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ id  ┆ q_item_id   ┆ q_level1_global_b ┆ q_item_name       ┆ q_link_first_imag ┆ q_item_name_clea │
# │ --- ┆ ---         ┆ e_category        ┆ ---               ┆ e                 ┆ n                │
# │ u32 ┆ i64         ┆ ---               ┆ str               ┆ ---               ┆ ---              │
# │     ┆             ┆ str               ┆                   ┆ str               ┆ str              │
# ╞═════╪═════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ 0   ┆ 25027814732 ┆ Men Shoes         ┆ Dép quai ngang    ┆ https://cf.shopee ┆ dép quai ngang   │
# │     ┆             ┆                   ┆ slipper Xé dán …  ┆ .sg/file/vn-1…    ┆ slipper xé dán … │
# │ 1   ┆ 898579880   ┆ Men Shoes         ┆ Xi Đánh Giày -    ┆ https://cf.shopee ┆ xi đánh giày -   │
# │     ┆             ┆                   ┆ Chuyên Dùng Đán…  ┆ .sg/file/sg-1…    ┆ chuyên dùng đán… │
# │ 2   ┆ 14885441590 ┆ Men Shoes         ┆ Giày Thể Thao     ┆ https://cf.shopee ┆ giày thể thao    │
# │     ┆             ┆                   ┆ BigSize Nam Năng… ┆ .sg/file/1124…    ┆ bigsize nam      │
# │     ┆             ┆                   ┆                   ┆                   ┆ năng…            │
# │ 3   ┆ 25974450598 ┆ Men Shoes         ┆ Chai Xịt Khử Mùi  ┆ https://cf.shopee ┆ chai xịt khử mùi │
# │     ┆             ┆                   ┆ Giày Dép NaNo…    ┆ .sg/file/vn-1…    ┆ giày dép nano…   │
# │ 4   ┆ 22289716536 ┆ Men Shoes         ┆ Giày sneaker vải  ┆ https://cf.shopee ┆ giày sneaker vải │
# │     ┆             ┆                   ┆ dệt đẳng cấp …    ┆ .sg/file/vn-1…    ┆ dệt đẳng cấp …   │
# └─────┴─────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %%
path_tmp_array = Path('tmp/array')
path_tmp_ds = Path('tmp/ds')
make_dir(path_tmp_ds)
make_dir(path_tmp_array)

file_embed = path_tmp_array / f'jina_embed.npy'
if not file_embed.exists():
    model = SentenceTransformer("jinaai/jina-embeddings-v3", trust_remote_code=True)
    task = 'text-matching'
    embeddings = model.encode(
        df['q_item_name_clean'].to_list(),
        task=task,
        prompt_name=task,
        show_progress_bar=True
    )
    np.save(file_embed, embeddings)
else:
    embeddings = np.load(file_embed)
print(embeddings.shape)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# ...
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# Flash attention implementation does not support kwargs: prompt_length
# (72110, 1024)

# %%
df = df.with_columns(pl.Series(values=embeddings, name='embed'))
dataset = Dataset.from_polars(df)
dataset.set_format(type='numpy', columns=['embed'], output_all_columns=True)

# %%
path_index = Path('tmp/index')
build_index(
    str(path_tmp_array),
    index_path=str(path_index / f'ip.index'),
    index_infos_path=str(path_index / f'index.json'),
    save_on_disk=True,
    metric_type='ip',
    verbose=30,
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 2345.81it/s]
# 100%|██████████| 6/6 [00:02<00:00,  2.06it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# (<faiss.swigfaiss_avx2.IndexHNSWFlat; proxy of <Swig Object of type 'faiss::IndexHNSWFlat *' at 0x7423dbb6f270> >,
#  {'index_key': 'HNSW32',
#   'index_param': 'efSearch=526',
#   'index_path': 'tmp/index/ip.index',
#   'size in bytes': 314987402,
#   'avg_search_speed_ms': 9.004521084566571,
#   '99p_search_speed_ms': 14.145050499064382,
#   'reconstruction error %': 0.0,
#   'nb vectors': 72110,
#   'vectors dimension': 1024,
#   'compression ratio': 0.9376964225381941})

# %%
# add index
dataset.load_faiss_index('embed', path_index / f'ip.index')

# %%
score, result = dataset.get_nearest_examples_batch(
    'embed',
    np.asarray(dataset['embed']),
    k=5
)

dict_ = {'score': [list(i) for i in score]}
df_score = pl.DataFrame(dict_)
df_result = (
    pl.DataFrame(result).drop(['embed'])
    .select(pl.all().name.prefix(f'db_'))
)

# %%
df_match = pl.concat([df.drop(['id']), df_result, df_score], how='horizontal')
col_explode = [i for i in df_match.columns if 'db' in i] + ['score']
df_match = df_match.explode(col_explode)

# %%
df_match
# Out:
# shape: (360_550, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ q_item_id ┆ q_level1_ ┆ q_item_na ┆ q_link_fi ┆ … ┆ db_q_item ┆ db_q_link ┆ db_q_item ┆ score    │
# │ ---       ┆ global_be ┆ me        ┆ rst_image ┆   ┆ _name     ┆ _first_im ┆ _name_cle ┆ ---      │
# │ i64       ┆ _category ┆ ---       ┆ ---       ┆   ┆ ---       ┆ age       ┆ an        ┆ f32      │
# │           ┆ ---       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆          │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆ str       ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 250278147 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.995602 │
# │ 32        ┆           ┆ ngang     ┆ f.shopee. ┆   ┆ ngang     ┆ f.shopee. ┆ ngang     ┆          │
# │           ┆           ┆ slipper   ┆ sg/file/v ┆   ┆ slipper   ┆ sg/file/v ┆ slipper   ┆          │
# │           ┆           ┆ Xé dán …  ┆ n-1…      ┆   ┆ Xé dán …  ┆ n-1…      ┆ xé dán …  ┆          │
# │ 250278147 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.912379 │
# │ 32        ┆           ┆ ngang     ┆ f.shopee. ┆   ┆ ngang     ┆ f.shopee. ┆ ngang     ┆          │
# │           ┆           ┆ slipper   ┆ sg/file/v ┆   ┆ slipper   ┆ sg/file/v ┆ slipper   ┆          │
# │           ┆           ┆ Xé dán …  ┆ n-1…      ┆   ┆ quai dá…  ┆ n-1…      ┆ quai dá…  ┆          │
# │ 250278147 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.893187 │
# │ 32        ┆           ┆ ngang     ┆ f.shopee. ┆   ┆ ngang     ┆ f.shopee. ┆ ngang     ┆          │
# │           ┆           ┆ slipper   ┆ sg/file/v ┆   ┆ slipper   ┆ sg/file/v ┆ slipper   ┆          │
# │           ┆           ┆ Xé dán …  ┆ n-1…      ┆   ┆ Xé dán …  ┆ n-1…      ┆ xé dán …  ┆          │
# │ 250278147 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.88825  │
# │ 32        ┆           ┆ ngang     ┆ f.shopee. ┆   ┆ ngang     ┆ f.shopee. ┆ ngang     ┆          │
# │           ┆           ┆ slipper   ┆ sg/file/v ┆   ┆ slipper   ┆ sg/file/v ┆ slipper   ┆          │
# │           ┆           ┆ Xé dán …  ┆ n-1…      ┆   ┆ Xé dán …  ┆ n-1…      ┆ xé dán …  ┆          │
# │ 250278147 ┆ Men Shoes ┆ Dép quai  ┆ https://c ┆ … ┆ Dép quai  ┆ https://c ┆ dép quai  ┆ 0.886416 │
# │ 32        ┆           ┆ ngang     ┆ f.shopee. ┆   ┆ ngang     ┆ f.shopee. ┆ ngang     ┆          │
# │           ┆           ┆ slipper   ┆ sg/file/v ┆   ┆ slipper   ┆ sg/file/v ┆ slipper   ┆          │
# │           ┆           ┆ Xé dán …  ┆ n-1…      ┆   ┆ Xé dán …  ┆ n-1…      ┆ xé dán …  ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 240651514 ┆ Men Shoes ┆ Giày      ┆ https://c ┆ … ┆ Giày      ┆ https://c ┆ giày      ┆ 1.005471 │
# │ 97        ┆           ┆ Slipon    ┆ f.shopee. ┆   ┆ Slipon    ┆ f.shopee. ┆ slipon    ┆          │
# │           ┆           ┆ Amiri     ┆ sg/file/v ┆   ┆ Amiri     ┆ sg/file/v ┆ amiri     ┆          │
# │           ┆           ┆ Nhung     ┆ n-1…      ┆   ┆ Nhung     ┆ n-1…      ┆ nhung     ┆          │
# │           ┆           ┆ Vạch D…   ┆           ┆   ┆ Vạch D…   ┆           ┆ vạch d…   ┆          │
# │ 240651514 ┆ Men Shoes ┆ Giày      ┆ https://c ┆ … ┆ Giày      ┆ https://c ┆ giày      ┆ 1.005471 │
# │ 97        ┆           ┆ Slipon    ┆ f.shopee. ┆   ┆ Slipon    ┆ f.shopee. ┆ slipon    ┆          │
# │           ┆           ┆ Amiri     ┆ sg/file/v ┆   ┆ Amiri     ┆ sg/file/v ┆ amiri     ┆          │
# │           ┆           ┆ Nhung     ┆ n-1…      ┆   ┆ Nhung     ┆ n-1…      ┆ nhung     ┆          │
# │           ┆           ┆ Vạch D…   ┆           ┆   ┆ Vạch D…   ┆           ┆ vạch d…   ┆          │
# │ 240651514 ┆ Men Shoes ┆ Giày      ┆ https://c ┆ … ┆ Giày      ┆ https://c ┆ giày      ┆ 0.910827 │
# │ 97        ┆           ┆ Slipon    ┆ f.shopee. ┆   ┆ Slipon    ┆ f.shopee. ┆ slipon    ┆          │
# │           ┆           ┆ Amiri     ┆ sg/file/v ┆   ┆ Amiri     ┆ sg/file/8 ┆ amiri     ┆          │
# │           ┆           ┆ Nhung     ┆ n-1…      ┆   ┆ Nhung     ┆ fcd…      ┆ nhung     ┆          │
# │           ┆           ┆ Vạch D…   ┆           ┆   ┆ Vạch D…   ┆           ┆ vạch d…   ┆          │
# │ 240651514 ┆ Men Shoes ┆ Giày      ┆ https://c ┆ … ┆ ⚡️[HÀNG   ┆ https://c ┆ ⚡️ - giày ┆ 0.815412 │
# │ 97        ┆           ┆ Slipon    ┆ f.shopee. ┆   ┆ CAO CẤP]  ┆ f.shopee. ┆ slip-on   ┆          │
# │           ┆           ┆ Amiri     ┆ sg/file/v ┆   ┆ - Giày    ┆ sg/file/v ┆ amiri     ┆          │
# │           ┆           ┆ Nhung     ┆ n-1…      ┆   ┆ Slip-o…   ┆ n-1…      ┆ xương …   ┆          │
# │           ┆           ┆ Vạch D…   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 240651514 ┆ Men Shoes ┆ Giày      ┆ https://c ┆ … ┆ Giầy      ┆ https://c ┆ giầy      ┆ 0.787514 │
# │ 97        ┆           ┆ Slipon    ┆ f.shopee. ┆   ┆ slipon    ┆ f.shopee. ┆ slipon    ┆          │
# │           ┆           ┆ Amiri     ┆ sg/file/v ┆   ┆ xương     ┆ sg/file/v ┆ xương     ┆          │
# │           ┆           ┆ Nhung     ┆ n-1…      ┆   ┆ Amiri -   ┆ n-1…      ┆ amiri -   ┆          │
# │           ┆           ┆ Vạch D…   ┆           ┆   ┆ giày…     ┆           ┆ giày…     ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
